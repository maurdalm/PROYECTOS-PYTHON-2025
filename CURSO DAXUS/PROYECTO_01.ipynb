# %% [markdown]
# # Proyecto 01

# %% [markdown]
# #  Mostrar informacion del usuario
#
# . Print

# %%
print("Semana de python en la practica")
print('Mauro es el mejor')
# Out:
# Semana de python en la practica
# Mauro es el mejor
